# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module

# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 4.1 MB/s eta 0:00:00a 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Load the twentieth-century text file.

# %%
# Load the 20th-century text file
with open('/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/CF_S1/20th-century/Scraped_data/timeline_20th_century_v4.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', ' ')

# %%
# Apply the NER algorithm to the data
book = NER(data)

# %%
# Fix spacing after punctuation or numbers
import re

# Add spaces after commas and periods if missing
data_clean = re.sub(r'(?<=[a-zA-Z])(?=[A-Z])', ' ', data)  # split joined words like "UnitedStates" → "United States"
data_clean = re.sub(r'(?<=\d)(?=[A-Z])', ' ', data_clean)  # e.g. 1900sJanuary → 1900s January
data_clean = re.sub(r'(?<=[a-z])(?=\d)', ' ', data_clean)  # e.g. "Warends1905" → "War ends 1905"

# Re-run NER
book = NER(data_clean)

# %%
displacy.render(book[0:1000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - January 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  coloniesfederate.[1]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - January 22
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edward V I Ibecame King of England
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  after
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Queen Victoria's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  death.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - March 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Platt Amendmentprovides
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cuban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  independence in exchange for the withdrawal of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  troops.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :Emily Hobhousereports on the poor conditions in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  internment camps for
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Boerwomen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and children in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South Africa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - September 6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : The assassination of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William Mc Kinleyushered
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in office Vice President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Theodore Rooseveltafter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Mc
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kinley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's death on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - September 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : The Eight-Nation Alliancedefeats the Boxer Rebellion, and imposes heavy financial penalties on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - December 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : First Nobel Prizesawarded.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1900s - December 12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# :Guglielmo Marconireceived the
# <mark class="entity" style="background: #

# %%
print(book.ents[:100])
# Out:
# (1900s - January 1, Australian, 1900s - January 22, Edward V I Ibecame King of England, India, Queen Victoria's, 1900s - March 2, The Platt Amendmentprovides, Cuban, American, 1900s - June, 45, British, Boerwomen, South Africa, 1900s - September 6, William Mc Kinleyushered, Theodore Rooseveltafter, Kinley, September 14, 1900s - September 7, China, 1900s - December 10, 1900s - December 12, first, 1900s - January 13, The Unification of Saudi Arabiabegins, 1900s - May 20, the United States, 1900s - May 31, Second Boer Warends, British, 1900s - July 12, Arthur Balfourbecomes, the United Kingdom, 1900s - July 17, Willis Carrierinvents, first, Venezuelan, 1902–1903, Britain, Germany, Italy, Venezuelain, 1900s - February 15, 1900s - June 11, Serbiaand, Queen Dragaare, 1900s - July 1, first, Tour de Franceis, 1900s - July, August, the Russian Social Democratic Labour Party, 1900s - August 4, Xbecomes Pope, 1900s - November 18, Panama, the United States, Panama, 1900s - December 17, First, Wright, 1900s, German, Berlin, Baghdad, 1900s - February 8, Port Arthur, the Russo-Japanese War, 1900s - April 8, Britain, France, 1900s - May, U.S., Panama Canaland, 1900s - June 21, Trans-Siberian Railwayis, Nama, first, the 20th century, German, Roger Casementpublisheshis, Belgian, the Congo Free State, 1900s - January 22, The Revolution of 1905, Russia, 1900s - March 31, First, April 1906.[5], 1900s - June 7, Norway, 1900s - September 5, The Russo-Japanese Warends, Japanese, 1900s - September 26, Albert Einstein's, 1900s - October 16, The British Indian Province)

# %% [markdown]
# ### Get named entity list per sentence

# %%
df_sentences = []

# Loop through each sentence in the text and collect its named entities
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})

# Convert to a DataFrame
df_sentences = pd.DataFrame(df_sentences)

# Preview
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (1900s, -, January, 1, :, The, Australian, col...
# 1  (1900s, -, March, 2, :, The, Platt, Amendmentp...
# 2  (1900s, -, June, :, Emily, Hobhousereports, on...
# 3  (1900s, -, September, 6, :, The, assassination...
# 4  (1900s, -, September, 7, :, The, Eight, -, Nat...
# 5  (1900s, -, December, 10, :, First, Nobel, Priz...
# 6  (1900s, -, January, 13, :, The, Unification, o...
# 7  (1900s, -, May, 20, :, Cubagiven, independence...
# 8  (1900s, -, May, 31, :, Second, Boer, Warends, ...
# 9  (1900s, -, July, 12, :, Arthur, Balfourbecomes...
#
#                                             entities
# 0  [1900s - January 1, Australian, 1900s - Januar...
# 1  [1900s - March 2, The Platt Amendmentprovides,...
# 2  [1900s - June, 45, British, Boerwomen, South A...
# 3  [1900s - September 6, William Mc Kinleyushered...
# 4                       [1900s - September 7, China]
# 5  [1900s - December 10, 1900s - December 12, first]
# 6  [1900s - January 13, The Unification of Saudi ...
# 7                [1900s - May 20, the United States]
# 8     [1900s - May 31, Second Boer Warends, British]
# 9  [1900s - July 12, Arthur Balfourbecomes, the U...

# %% [markdown]
# ### Load country names

# %%
file_path = "/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/CF_S1/20th-century/Scraped_data/countries_list.txt"

with open(file_path, 'r') as f:
    country_list = [line.strip() for line in f if line.strip() != '']

# Create DataFrame of country names
country_df = pd.DataFrame({'country_alias': country_list})

# %%
country_df
# Out:
#         country_alias
# 0    sovereign states
# 1         Afghanistan
# 2             Albania
# 3             Algeria
# 4             Andorra
# ..                ...
# 362            Adjara
# 363            Adygea
# 364             Altai
# 365        Bangsamoro
# 366     Bashkortostan
#
# [367 rows x 1 columns]

# %% [markdown]
# ### Filter Named Entities by Country List

# %%
Filter Named Entities by Country List

# %%
# Define function to keep only countries in entity list
def filter_entity(ent_list, country_df):
    return [ent for ent in ent_list if ent in list(country_df['country_alias'])]

# Apply to each sentence's entity list
df_sentences['country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, country_df))

# Keep only sentences that mention at least 1 country
df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]

# %%
df_sentences_filtered.head()
# Out:
#                                              sentence  \
# 0   (1900s, -, January, 1, :, The, Australian, col...
# 2   (1900s, -, June, :, Emily, Hobhousereports, on...
# 4   (1900s, -, September, 7, :, The, Eight, -, Nat...
# 11  (1900s, -, Venezuelan, crisis, of, 1902–1903, ...
# 16  (1900s, -, August, 4, :, Pius, Xbecomes, Pope,...
#
#                                              entities  country_entities
# 0   [1900s - January 1, Australian, 1900s - Januar...           [India]
# 2   [1900s - June, 45, British, Boerwomen, South A...    [South Africa]
# 4                        [1900s - September 7, China]           [China]
# 11  [Venezuelan, 1902–1903, Britain, Germany, Ital...  [Germany, Italy]
# 16  [1900s - August 4, Xbecomes Pope, 1900s - Nove...  [Panama, Panama]

# %% [markdown]
# ### Create relationships

# %%
# Define how many sentences to look at together
window_size = 5
relationships = []

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i + window_size, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i:end_i].country_entities), [])

    # Remove duplicates that are next to each other
    char_unique = [char_list[j] for j in range(len(char_list)) 
                   if j == 0 or char_list[j] != char_list[j - 1]]

    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)
relationship_df.head(10)
# Out:
#          source        target
# 0         India  South Africa
# 1  South Africa         China
# 2  South Africa         China
# 3  South Africa         China
# 4       Germany         Italy
# 5       Germany         Italy
# 6       Germany         Italy
# 7       Germany         Italy
# 8       Germany         Italy
# 9       Germany         Italy

# %%
# Sort country pairs alphabetically (so "France–Germany" and "Germany–France" are treated the same)
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis=1), columns=relationship_df.columns)

# Add a value column for counting
relationship_df["value"] = 1

# Group and count occurrences of each country pair
relationship_df = relationship_df.groupby(["source", "target"], sort=False, as_index=False).sum()

# Preview
relationship_df.head(10)
# Out:
#     source        target  value
# 0    India  South Africa      1
# 1    China  South Africa      3
# 2  Germany         Italy     10
# 3    Italy        Panama      1
# 4   France        Panama      3
# 5   France        Russia      1
# 6   Norway        Russia      5
# 7    Chile        France      2
# 8    Chile          Cuba      6
# 9     Cuba        Russia      5

# %% [markdown]
# ### Export Relationship Data

# %%
output_path = "/Users/emilsafarov/Library/CloudStorage/OneDrive-Personal/CF/CF_S1/20th-century/Scraped_data/country_relationships.csv"

relationship_df.to_csv(output_path, index=False)
